# %%
import pandas as pd
import numpy as np
df=pd.read_csv('Cleaned_Exoplanets_data.csv')
df_new = pd.read_csv('Parallax.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6128 entries, 0 to 6127
# Data columns (total 20 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   pl_name                                  6128 non-null   object
#  1   Star's name                              6128 non-null   object
#  2   sy_snum                                  6128 non-null   int64
#  3   sy_pnum                                  6128 non-null   int64
#  4   discoverymethod                          6128 non-null   object
#  5   disc_year                                6127 non-null   float64
#  6   pl_orb_period(in days)                   5776 non-null   float64
#  7   pl_orb_period(in E.years)                6128 non-null   float64
#  8   pl_orb_semi_maj_axis(in AU)              3821 non-null   float64
#  9   pl_orb_eccent                            2586 non-null   float64
# ...

# %%
df_new.info()

# %%
df.head()
# Out:
#       pl_name Star's name  sy_snum  sy_pnum  discoverymethod  disc_year  \
# 0    11 Com b      11 Com        2        1  Radial Velocity     2007.0
# 1    11 UMi b      11 UMi        1        1  Radial Velocity     2009.0
# 2    14 And b      14 And        1        1  Radial Velocity     2008.0
# 3    14 Her b      14 Her        1        2  Radial Velocity     2002.0
# 4  16 Cyg B b    16 Cyg B        3        1  Radial Velocity     1996.0
#
#    pl_orb_period(in days)  pl_orb_period(in E.years)  \
# 0               323.21000                   0.884392
# 1               516.21997                   1.135049
# 2               186.76000                   0.511379
# 3              1765.03890                   4.843273
# 4               798.50000                   2.058023
#
#    pl_orb_semi_maj_axis(in AU)  pl_orb_eccent  pl_rad(in Earth Radius)  \
# 0                        1.178          0.238                      NaN
# ...

# %%
df_new.head()

# %%
df.isnull().sum()
# Out:
# pl_name                                       0
# Star's name                                   0
# sy_snum                                       0
# sy_pnum                                       0
# discoverymethod                               0
# disc_year                                     1
# pl_orb_period(in days)                      352
# pl_orb_period(in E.years)                     0
# pl_orb_semi_maj_axis(in AU)                2307
# pl_orb_eccent                              3542
# pl_rad(in Earth Radius)                    1575
# pl_bmass(in Earth Mass)                    3102
# pl_dens(in (Earth mass/Earth radius))      1575
# st_teff(in kelvin)                          711
# st_rad(in solar radius)                     798
# st_mass(in solar mass)                      773
# sy_dist(in Parsec)                          135
# pl_teff(in kelvin)                         2307
# st_lum(in Solar luminosity)                   0
# pl_recei_flux(in Earth's received flux)    2307
# ...

# %%
df_new.isnull().sum()

# %%
df.to_csv('new_cleaned_exoplanets.csv', index=False)
df_new.to_csv('new_parallax.csv', index=False)
